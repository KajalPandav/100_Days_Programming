# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
ipl = pd.read_csv(r"C:\Users\Kajal\Desktop\ssd\Desktop\dataset work November\datasets\datasets 1\datasets ipl match\matches.csv")

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  04-05-2017          Sunrisers Hyderabad
# 1      2    2017       Pune  04-06-2017               Mumbai Indians
# 2      3    2017     Rajkot  04-07-2017                Gujarat Lions
# 3      4    2017     Indore  04-08-2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  04-08-2017  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 665  666    2018       Pune      30-Apr          Chennai Super Kings
# 666  667    2018  Bangalore      01-May  Royal Challengers Bangalore
# 667  668    2018      Delhi      02-May             Delhi Daredevils
# 668  669    2018    Kolkata      03-May        Kolkata Knight Riders
# 669  670    2018     Indore      04-May              Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # info

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670 entries, 0 to 669
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               670 non-null    int64
#  1   season           670 non-null    int64
#  2   city             670 non-null    object
#  3   date             670 non-null    object
#  4   team1            670 non-null    object
#  5   team2            670 non-null    object
#  6   toss_winner      670 non-null    object
#  7   toss_decision    670 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    float64
#  10  winner           670 non-null    object
#  11  win_by_runs      636 non-null    float64
#  12  win_by_wickets   636 non-null    float64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
# ...

# %% [markdown]
# # describe

# %%
ipl.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  670.000000   670.000000  636.000000   636.000000      636.000000
# mean   335.500000  2012.770149    0.025157    13.682390        3.372642
# std    193.556624     2.960276    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    168.250000  2010.000000    0.000000     0.000000        0.000000
# 50%    335.500000  2013.000000    0.000000     0.000000        4.000000
# 75%    502.750000  2015.000000    0.000000    20.000000        7.000000
# max    670.000000  2018.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# # Check null values

# %%
ipl.isnull().any()
# Out:
# id                 False
# season             False
# city               False
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result              True
# dl_applied          True
# winner             False
# win_by_runs         True
# win_by_wickets      True
# player_of_match     True
# venue               True
# umpire1             True
# umpire2             True
# umpire3             True
# dtype: bool

# %%
ipl.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result              34
# dl_applied          34
# winner               0
# win_by_runs         34
# win_by_wickets      34
# player_of_match     37
# venue               34
# umpire1             35
# umpire2             35
# umpire3            670
# dtype: int64

# %% [markdown]
# # Data Analysis using problem statements

# %% [markdown]
# # Q.1 Find out team_2 Royal Challengers Bangalore data and toss_winner Count

# %%
toss = ipl.loc[(ipl["team2"]=="Royal Challengers Bangalore") & (ipl["toss_winner"]=="Royal Challengers Bangalore"),["team2","toss_winner"]]

# %%
toss
# Out:
#                            team2                  toss_winner
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore
# 16   Royal Challengers Bangalore  Royal Challengers Bangalore
# 26   Royal Challengers Bangalore  Royal Challengers Bangalore
# 32   Royal Challengers Bangalore  Royal Challengers Bangalore
# 41   Royal Challengers Bangalore  Royal Challengers Bangalore
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore
# 75   Royal Challengers Bangalore  Royal Challengers Bangalore
# 100  Royal Challengers Bangalore  Royal Challengers Bangalore
# 155  Royal Challengers Bangalore  Royal Challengers Bangalore
# 172  Royal Challengers Bangalore  Royal Challengers Bangalore
# 173  Royal Challengers Bangalore  Royal Challengers Bangalore
# 183  Royal Challengers Bangalore  Royal Challengers Bangalore
# 196  Royal Challengers Bangalore  Royal Challengers Bangalore
# 216  Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
toss.count()
# Out:
# team2          54
# toss_winner    54
# dtype: int64

# %% [markdown]
# # Q.2 Find the Season 2017 match winner team names with its count

# %%
winner = ipl.loc[(ipl["season"]==2017),["season","winner"]]

# %%
winner
# Out:
#     season                       winner
# 0     2017          Sunrisers Hyderabad
# 1     2017       Rising Pune Supergiant
# 2     2017        Kolkata Knight Riders
# 3     2017              Kings XI Punjab
# 4     2017  Royal Challengers Bangalore
# 5     2017          Sunrisers Hyderabad
# 6     2017               Mumbai Indians
# 7     2017              Kings XI Punjab
# 8     2017             Delhi Daredevils
# 9     2017               Mumbai Indians
# 10    2017        Kolkata Knight Riders
# 11    2017               Mumbai Indians
# 12    2017                Gujarat Lions
# 13    2017        Kolkata Knight Riders
# 14    2017             Delhi Daredevils
# 15    2017               Mumbai Indians
# 16    2017       Rising Pune Supergiant
# 17    2017        Kolkata Knight Riders
# 18    2017          Sunrisers Hyderabad
# 19    2017  Royal Challengers Bangalore
# 20    2017          Sunrisers Hyderabad
# 21    2017               Mumbai Indians
# ...

# %%
winner["winner"].value_counts()
# Out:
# Mumbai Indians                 12
# Rising Pune Supergiant         10
# Kolkata Knight Riders           9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Delhi Daredevils                6
# Gujarat Lions                   4
# Royal Challengers Bangalore     3
# Name: winner, dtype: int64

# %% [markdown]
# # Q.3 Find the team_1 Kings XI Punjab & team_2 mumbai indians data and calculate the mumbai indians winning & toss winning Count

# %%
team1_2 = ipl.loc[(ipl["team1"]=="Kings XI Punjab") & (ipl["team2"]=="Mumbai Indians") & (ipl["winner"]=="Mumbai Indians") & (ipl["toss_winner"]=="Mumbai Indians")]

# %%
team1_2
# Out:
#       id  season        city       date            team1           team2  \
# 21    22    2017      Indore  4/20/2017  Kings XI Punjab  Mumbai Indians
# 200  201    2010      Mumbai  3/30/2010  Kings XI Punjab  Mumbai Indians
# 504  505    2014  Chandigarh  5/21/2014  Kings XI Punjab  Mumbai Indians
# 669  670    2018      Indore     04-May  Kings XI Punjab  Mumbai Indians
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 21   Mumbai Indians         field  normal         0.0  Mumbai Indians
# 200  Mumbai Indians         field  normal         0.0  Mumbai Indians
# 504  Mumbai Indians         field  normal         0.0  Mumbai Indians
# 669  Mumbai Indians         field     NaN         NaN  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match  \
# 21           0.0             8.0      JC Buttler
# 200          0.0             4.0      SL Malinga
# 504          0.0             7.0     LMP Simmons
# ...

# %%
MI = team1_2[["team1","team2","toss_winner","winner"]]

# %%
MI
# Out:
#                team1           team2     toss_winner          winner
# 21   Kings XI Punjab  Mumbai Indians  Mumbai Indians  Mumbai Indians
# 200  Kings XI Punjab  Mumbai Indians  Mumbai Indians  Mumbai Indians
# 504  Kings XI Punjab  Mumbai Indians  Mumbai Indians  Mumbai Indians
# 669  Kings XI Punjab  Mumbai Indians  Mumbai Indians  Mumbai Indians

# %% [markdown]
# # Q.4 Slice the data team_1 Gujarat Lions & player of the match is Rashid Khan

# %%
GL = ipl.loc[(ipl["team1"]=="Gujarat Lions") & (ipl["player_of_match"]=="Rashid Khan")]

# %%
GL
# Out:
#    id  season       city        date          team1                team2  \
# 5   6    2017  Hyderabad  04-09-2017  Gujarat Lions  Sunrisers Hyderabad
#
#            toss_winner toss_decision  result  dl_applied               winner  \
# 5  Sunrisers Hyderabad         field  normal         0.0  Sunrisers Hyderabad
#
#    win_by_runs  win_by_wickets player_of_match  \
# 5          0.0             9.0     Rashid Khan
#
#                                        venue     umpire1   umpire2  umpire3
# 5  Rajiv Gandhi International Stadium, Uppal  A Deshmukh  NJ Llong      NaN
