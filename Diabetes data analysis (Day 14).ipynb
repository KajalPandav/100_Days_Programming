# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r"C:\Users\Kajal\Desktop\ssd\Desktop\dataset work November\datasets\diabetes.csv")
dataset
# Out:
#      Person  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0         6      148             72             35        0  33.6
# 1         1       85             66             29        0  26.6
# 2         8      183             64              0        0  23.3
# 3         1       89             66             23       94  28.1
# 4         0      137             40             35      168  43.1
# ..      ...      ...            ...            ...      ...   ...
# 763      10      101             76             48      180  32.9
# 764       2      122             70             27        0  36.8
# 765       5      121             72             23      112  26.2
# 766       1      126             60              0        0  30.1
# 767       1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Person                    768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.describe()
# Out:
#            Person     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     3.845052  120.894531      69.105469      20.536458   79.799479
# std      3.369578   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      1.000000   99.000000      62.000000       0.000000    0.000000
# 50%      3.000000  117.000000      72.000000      23.000000   30.500000
# 75%      6.000000  140.250000      80.000000      32.000000  127.250000
# max     17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.isnull().any()
# Out:
# Person                      False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# Person                      0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## Q.1) Find out count of people having diabetes

# %%
dia_1 = dataset.loc[(dataset["Outcome"]==1)]      # having diabetes
dia_1
# Out:
#      Person  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0         6      148             72             35        0  33.6
# 2         8      183             64              0        0  23.3
# 4         0      137             40             35      168  43.1
# 6         3       78             50             32       88  31.0
# 8         2      197             70             45      543  30.5
# ..      ...      ...            ...            ...      ...   ...
# 755       1      128             88             39      110  36.5
# 757       0      123             72              0        0  36.3
# 759       6      190             92              0        0  35.5
# 761       9      170             74             31        0  44.0
# 766       1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 2                       0.672   32        1
# ...

# %%
dia_1["Outcome"].value_counts()
# Out:
# 1    268
# Name: Outcome, dtype: int64

# %%
dia_0 = dataset.loc[(dataset["Outcome"]==0)]      # not having diabetes
dia_0
# Out:
#      Person  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1         1       85             66             29        0  26.6
# 3         1       89             66             23       94  28.1
# 5         5      116             74              0        0  25.6
# 7        10      115              0              0        0  35.3
# 10        4      110             92              0        0  37.6
# ..      ...      ...            ...            ...      ...   ...
# 762       9       89             62              0        0  22.5
# 763      10      101             76             48      180  32.9
# 764       2      122             70             27        0  36.8
# 765       5      121             72             23      112  26.2
# 767       1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# 3                       0.167   21        0
# ...

# %%
dia_0["Outcome"].value_counts()
# Out:
# 0    500
# Name: Outcome, dtype: int64

# %% [markdown]
# ## Q.2) Calculate count of person

# %%
per = dataset["Person"].value_counts()
per
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Person, dtype: int64

# %%
per.head()
# Out:
# 1    135
# 0    111
# 2    103
# 3     75
# 4     68
# Name: Person, dtype: int64

# %% [markdown]
# ## Q.3) Blood pressure rate of age-group less than 30

# %%
bp = dataset.loc[(dataset["Age"]<=30)]
bp
# Out:
#      Person  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3         1       89             66             23       94  28.1
# 5         5      116             74              0        0  25.6
# 6         3       78             50             32       88  31.0
# 7        10      115              0              0        0  35.3
# 10        4      110             92              0        0  37.6
# ..      ...      ...            ...            ...      ...   ...
# 758       1      106             76              0        0  37.5
# 760       2       88             58             26       16  28.4
# 764       2      122             70             27        0  36.8
# 765       5      121             72             23      112  26.2
# 767       1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# 5                       0.201   30        0
# ...

# %%
asc = bp.sort_values(by='Age',ascending=True)
asc
# Out:
#      Person  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3         1       89             66             23       94  28.1
# 507       1      130             60             23      170  28.6
# 190       3      111             62              0        0  22.6
# 508       2       84             50             23       76  30.4
# 511       0      139             62             17      210  22.1
# ..      ...      ...            ...            ...      ...   ...
# 444       4      117             62             12        0  29.7
# 256       3      111             56             39        0  30.1
# 765       5      121             72             23      112  26.2
# 10        4      110             92              0        0  37.6
# 300       0      167              0              0        0  32.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# 507                     0.692   21        0
# ...

# %% [markdown]
# ## Q.4) Calculate highest rate of insulin

# %%
insulin = dataset["Insulin"].value_counts()
insulin
# Out:
# 0      374
# 105     11
# 140      9
# 130      9
# 120      8
#       ...
# 271      1
# 270      1
# 108      1
# 112      1
# 846      1
# Name: Insulin, Length: 186, dtype: int64

# %%
insulin.head()
# Out:
# 0      374
# 105     11
# 140      9
# 130      9
# 120      8
# Name: Insulin, dtype: int64

# %% [markdown]
# ## Q.5) Highest sugar rate between age 50-70

# %%
high = dataset[["Glucose","Age"]]
high
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 763      101   63
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
#
# [768 rows x 2 columns]

# %%
high_glu = high.loc[(high["Age"]>=50) & (high["Age"]<=70)]
high_glu
# Out:
#      Glucose  Age
# 0        148   50
# 8        197   53
# 9        125   54
# 12       139   57
# 13       189   59
# ..       ...  ...
# 734      105   53
# 749      162   50
# 757      123   52
# 759      190   66
# 763      101   63
#
# [87 rows x 2 columns]

# %%
print("Glucose::",high_glu["Glucose"].max())
print("Age::",high_glu["Age"].max())
# Out:
# Glucose:: 197
# Age:: 70

# %% [markdown]
# ## Q.6) Find out low BP range with age

# %%
low = dataset[["BloodPressure","Age"]]
low
# Out:
#      BloodPressure  Age
# 0               72   50
# 1               66   31
# 2               64   32
# 3               66   21
# 4               40   33
# ..             ...  ...
# 763             76   63
# 764             70   27
# 765             72   30
# 766             60   47
# 767             70   23
#
# [768 rows x 2 columns]

# %%
asc1 = low.sort_values(by=['BloodPressure','Age'],ascending=True)
asc1
# Out:
#      BloodPressure  Age
# 60               0   21
# 81               0   22
# 494              0   22
# 697              0   22
# 347              0   23
# ..             ...  ...
# 177            110   26
# 549            110   37
# 43             110   54
# 691            114   44
# 106            122   27
#
# [768 rows x 2 columns]
