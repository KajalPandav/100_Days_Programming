# %%
import numpy as np
import pandas as pd

# %%
weather = pd.read_csv(r"C:\Users\Kajal\Desktop\ssd\March coding work\New_Weather_AUS.csv")
weather
# Out:
#               Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4  22.900000       0.6     5.468232
# 1       2008-12-02   Albury      7.4  25.100000       0.0     5.468232
# 2       2008-12-03   Albury     12.9  25.700000       0.0     5.468232
# 3       2008-12-04   Albury      9.2  28.000000       0.0     5.468232
# 4       2008-12-05   Albury     17.5  32.300000       1.0     5.468232
# ...            ...      ...      ...        ...       ...          ...
# 145455  2017-06-21    Uluru      2.8  23.400000       0.0     5.468232
# 145456  2017-06-22    Uluru      3.6  25.300000       0.0     5.468232
# 145457  2017-06-23    Uluru      5.4  26.900000       0.0     5.468232
# 145458  2017-06-24    Uluru      7.8  27.000000       0.0     5.468232
# 145459  2017-06-25    Uluru     14.9  23.221348       0.0     5.468232
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        145460 non-null  float64
#  3   MaxTemp        145460 non-null  float64
#  4   Rainfall       145460 non-null  float64
#  5   Evaporation    145460 non-null  float64
#  6   Sunshine       145460 non-null  float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  145460 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    145460 non-null  float64
#  14  Humidity3pm    145460 non-null  float64
#  15  Pressure9am    145460 non-null  float64
# ...

# %%
weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean       12.194034      23.221348       2.360918       5.468232
# std         6.365750       7.088124       8.382488       3.161541
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.100000      22.700000       0.000000       5.468232
# 75%        16.800000      28.200000       1.000000       5.468232
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  145460.000000  143693.000000  142398.000000
# mean        7.611178      40.035230      14.043426      18.662657
# std         2.729486      13.118253       8.915375       8.809800
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
weather.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine         False
# WindGustDir       True
# WindGustSpeed    False
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm      True
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm       True
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday         True
# RainTomorrow      True
# dtype: bool

# %% [markdown]
# # checking null values

# %%
weather.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm      15028
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # Replace null values

# %%
weather["WindGustDir"].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
weather["WindDir9am"].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
weather["WindDir3pm"].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
weather["WindSpeed9am"].unique()
# Out:
# array([ 20.,   4.,  19.,  11.,   7.,   6.,  15.,  17.,  28.,  24.,  nan,
#          9.,   0.,  13.,   2.,  26.,  30.,  22.,  35.,  37.,  31.,  33.,
#         48.,  39.,  44.,  43.,  41.,  46.,  56.,  83.,  74.,  52.,  65.,
#         50., 130.,  54.,  61.,  57.,  59.,  87.,  67.,  63.,  69.,  72.])

# %%
weather["WindSpeed3pm"].unique()
# Out:
# array([24., 22., 26.,  9., 20., 17., 28., 11.,  6., 13., 30., 19., 31.,
#         7., 15., 48.,  4., 33.,  0.,  2., nan, 37., 46., 39., 50., 35.,
#        44., 41., 43., 56., 61., 54., 52., 83., 65., 78., 57., 63., 59.,
#        74., 72., 69., 76., 87., 67.])

# %%
weather["Pressure3pm"].unique()
# Out:
# array([1007.1  , 1007.8  , 1008.7  , 1012.8  , 1006.   , 1005.4  ,
#        1008.2  , 1010.1  , 1003.6  , 1005.7  , 1004.2  ,  993.   ,
#        1001.8  , 1010.3  , 1010.4  , 1002.2  , 1009.7  , 1017.1  ,
#        1014.8  , 1008.1  , 1007.6  , 1001.7  , 1003.4  , 1005.1  ,
#        1003.2  , 1013.1  , 1009.2  , 1006.7  , 1002.7  , 1010.9  ,
#        1013.7  , 1006.8  , 1012.1  , 1006.9  , 1012.7  , 1017.4  ,
#        1016.2  , 1010.6  , 1004.8  , 1005.9  ,  997.8  , 1003.9  ,
#        1014.6  , 1014.1  , 1011.6  , 1011.8  , 1010.2  , 1010.5  ,
#        1007.4  , 1004.7  , 1002.6  , 1005.   , 1003.8  , 1006.5  ,
#        1008.5  , 1011.1  , 1017.3  , 1019.7  , 1016.4  , 1013.8  ,
#        1013.5  , 1007.5  , 1004.5  , 1010.8  , 1012.4  , 1013.4  ,
#        1015.   , 1012.6  , 1004.6  , 1009.   , 1012.   , 1014.7  ,
#        1015.9  , 1018.   , 1018.9  , 1008.   , 1013.2  , 1013.9  ,
#        1013.6  , 1014.4  , 1019.2  , 1017.2  , 1020.7  , 1020.6  ,
# ...

# %%
weather["RainToday"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
weather["RainTomorrow"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
weather["WindGustDir"].fillna("EE",inplace=True)
weather["WindDir9am"].fillna("AF",inplace=True)
weather["WindDir3pm"].fillna("SSS",inplace=True)
weather["WindSpeed9am"].fillna(200,inplace=True)
weather["WindSpeed3pm"].fillna(300,inplace=True)
weather["Pressure3pm"].fillna(100,inplace=True)
weather["RainToday"].fillna("EE",inplace=True)
weather["RainTomorrow"].fillna("EE",inplace=True)

# %%
weather.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
weather.to_csv("New2_weatherAUS.csv",index=False)
new_AUS = pd.read_csv("New2_weatherAUS.csv")
new_AUS
# Out:
#               Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4  22.900000       0.6     5.468232
# 1       2008-12-02   Albury      7.4  25.100000       0.0     5.468232
# 2       2008-12-03   Albury     12.9  25.700000       0.0     5.468232
# 3       2008-12-04   Albury      9.2  28.000000       0.0     5.468232
# 4       2008-12-05   Albury     17.5  32.300000       1.0     5.468232
# ...            ...      ...      ...        ...       ...          ...
# 145455  2017-06-21    Uluru      2.8  23.400000       0.0     5.468232
# 145456  2017-06-22    Uluru      3.6  25.300000       0.0     5.468232
# 145457  2017-06-23    Uluru      5.4  26.900000       0.0     5.468232
# 145458  2017-06-24    Uluru      7.8  27.000000       0.0     5.468232
# 145459  2017-06-25    Uluru     14.9  23.221348       0.0     5.468232
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
new_AUS["Date"].unique()
# Out:
# array(['2008-12-01', '2008-12-02', '2008-12-03', ..., '2008-01-29',
#        '2008-01-30', '2008-01-31'], dtype=object)

# %% [markdown]
# # Q.1. Find the Uluru mintemp & maxtemp between 2017-06-21 to 2017-06-25

# %%
aa = new_AUS[['Date','Location','MinTemp','MaxTemp']]
aa
# Out:
#               Date Location  MinTemp    MaxTemp
# 0       2008-12-01   Albury     13.4  22.900000
# 1       2008-12-02   Albury      7.4  25.100000
# 2       2008-12-03   Albury     12.9  25.700000
# 3       2008-12-04   Albury      9.2  28.000000
# 4       2008-12-05   Albury     17.5  32.300000
# ...            ...      ...      ...        ...
# 145455  2017-06-21    Uluru      2.8  23.400000
# 145456  2017-06-22    Uluru      3.6  25.300000
# 145457  2017-06-23    Uluru      5.4  26.900000
# 145458  2017-06-24    Uluru      7.8  27.000000
# 145459  2017-06-25    Uluru     14.9  23.221348
#
# [145460 rows x 4 columns]

# %%
UU = aa.loc[(aa["Date"]>="2017-06-21") & (aa["Date"]<="2017-06-25") & (aa["Location"]=="Uluru")]

# %%
UU
# Out:
#               Date Location  MinTemp    MaxTemp
# 145455  2017-06-21    Uluru      2.8  23.400000
# 145456  2017-06-22    Uluru      3.6  25.300000
# 145457  2017-06-23    Uluru      5.4  26.900000
# 145458  2017-06-24    Uluru      7.8  27.000000
# 145459  2017-06-25    Uluru     14.9  23.221348

# %% [markdown]
# # Q.2. Slice the Richmond data with the humidity9am & humidity3pm

# %%
rich = new_AUS.loc[(new_AUS["Location"]=="Richmond"),["Location","Humidity9am","Humidity3pm"]]

# %%
rich
# Out:
#        Location  Humidity9am  Humidity3pm
# 27167  Richmond    68.880831    51.539116
# 27168  Richmond    68.880831    51.539116
# 27169  Richmond    68.880831    51.539116
# 27170  Richmond    68.880831    51.539116
# 27171  Richmond    68.880831    51.539116
# ...         ...          ...          ...
# 30171  Richmond    99.000000    67.000000
# 30172  Richmond    91.000000    60.000000
# 30173  Richmond    99.000000    71.000000
# 30174  Richmond    85.000000    39.000000
# 30175  Richmond    88.000000    35.000000
#
# [3009 rows x 3 columns]
